# %%
import scipy.integrate as sci
import numpy as np
from math import pi, sin, cos
from matplotlib import pyplot
from mpl_toolkits.mplot3d import Axes3D

# %%
N=50
x=np.linspace(-5,5,N)
y=np.linspace(-5,5,N)
v=np.zeros((N,N))
for i in range(N):
    for j in range(N):
        f = lambda x0: 2*x0/np.sqrt((x[i] - x0)**2 + y[j]**2)
        v[i,j] = sci.romberg(f,0,1)

fig = pyplot.figure()
ax = fig.gca(projection='3d')
X, Y = np.meshgrid(x, y)
surf = ax.plot_surface(X, Y, v,rstride=1, cstride=1,
                cmap='viridis', edgecolor='none')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('V(x,y)')        
Ex=-np.gradient(v,axis=-1)
Ey=-np.gradient(v,axis=0)
E=np.zeros((N,N))
E=np.sqrt(np.square(Ex)+np.square(Ey))
fig = pyplot.figure()
ax = fig.gca(projection='3d')
X, Y = np.meshgrid(x, y)
surf = ax.plot_surface(X, Y, E,rstride=1, cstride=1,
                cmap='viridis', edgecolor='none')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('E(x,y)')
# Out:
# Text(0.5,0,'E(x,y)')

# %%
N=20
x=np.linspace(-0.5,1.5,N)
y=np.linspace(0.5,2.5,N)
v1=np.zeros((N,N))
v2=np.zeros((N,N))
v=np.zeros((N,N))
for i in range(N) :
    for j in range(N) :
        f1=lambda x0: x0**2/np.sqrt((x[i]-x0)**2+(y[j]-1)**2)
        f2=lambda y0: y0/np.sqrt(x[i]**2+(y[j]-y0)**2)
        v1[i,j]=sci.romberg(f1,0,1)
        v2[i,j]=sci.romberg(f2,1,2)
        v[i,j]=v1[i,j]+v2[i,j]
    
fig = pyplot.figure()
ax = fig.gca(projection='3d')
X, Y = np.meshgrid(x, y)
surf = ax.plot_surface(X, Y, v,rstride=1, cstride=1,
                cmap='viridis', edgecolor='none')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('V(x,y)')
Ex=-np.gradient(v,axis=-1)
Ey=-np.gradient(v,axis=0)
E=np.zeros((len(Ex),len(Ey)))
E=np.sqrt(np.square(Ex)+np.square(Ey))
fig = pyplot.figure()
ax = fig.gca(projection='3d')
X, Y = np.meshgrid(x, y)
surf = ax.plot_surface(X, Y, E,rstride=1, cstride=1,
                cmap='viridis', edgecolor='none')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('|E(x,y)|')
# Out:
# Text(0.5,0,'|E(x,y)|')

# %%
N=20
x=np.linspace(-5,5,N)
y=np.linspace(-5,5,N)
z=2
v=np.zeros((N,N))
for i in range(N) :
    for j in range(N) :
        f=lambda r,theta : cos(theta)*r**2/np.sqrt((x[i]-r*cos(theta))**2 + (y[j]-r*sin(theta))**2 + z**2 )
        integral=sci.nquad(f,[[0,2],[0,2*pi]])
        v[i,j]=integral[0]    
 
fig = pyplot.figure()
ax = fig.gca(projection='3d')
X, Y = np.meshgrid(x, y)
surf = ax.plot_surface(X, Y, v,rstride=1, cstride=1,
                cmap='viridis', edgecolor='none')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('V(x,y)')
Ex=-np.gradient(v,axis=-1)
Ey=-np.gradient(v,axis=0)
E=np.zeros((N,N))
E=np.sqrt(np.square(Ex)+np.square(Ey))
fig = pyplot.figure()
ax = fig.gca(projection='3d')
X, Y = np.meshgrid(x, y)
surf = ax.plot_surface(X, Y, E,rstride=1, cstride=1,
                cmap='viridis', edgecolor='none')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('|E(x,y)|')
# Out:
# Text(0.5,0,'|E(x,y)|')
