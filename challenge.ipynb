# %%
import scipy.integrate as sci
import numpy as np
from matplotlib import pyplot

N=100
d=4/N
a=np.linspace(0,4,100)
T=np.zeros((N))
for i in range(N):
    a[i]=d+(i-1)*d
    f = lambda x:1/np.sqrt(8*(a[i]**4-x**4))
    T[i]=sci.romberg(f,0,a[i]-0.01)

pyplot.plot(a,T)
# Out:
# D:\APP\Anaconda\lib\site-packages\ipykernel_launcher.py:11: RuntimeWarning: divide by zero encountered in double_scalars
#   # This is added back by InteractiveShellApp.init_path()
# D:\APP\Anaconda\lib\site-packages\ipykernel_launcher.py:11: RuntimeWarning: invalid value encountered in sqrt
#   # This is added back by InteractiveShellApp.init_path()
# D:\APP\Anaconda\lib\site-packages\scipy\integrate\quadrature.py:752: AccuracyWarning: divmax (10) exceeded. Latest difference = nan
#   AccuracyWarning)
# D:\APP\Anaconda\lib\site-packages\scipy\integrate\quadrature.py:752: AccuracyWarning: divmax (10) exceeded. Latest difference = 1.772480e-08
#   AccuracyWarning)
# D:\APP\Anaconda\lib\site-packages\scipy\integrate\quadrature.py:752: AccuracyWarning: divmax (10) exceeded. Latest difference = 2.113231e-08
#   AccuracyWarning)
# D:\APP\Anaconda\lib\site-packages\scipy\integrate\quadrature.py:752: AccuracyWarning: divmax (10) exceeded. Latest difference = 2.496881e-08
# ...
