# %%
import scipy.integrate as sci
import numpy as np
from matplotlib import pyplot

N=50
d=4/N
a=np.linspace(0,4,N)
T=np.zeros((N))
for i in range(N):
    a[i]=d+i*d
    f = lambda x:1/np.sqrt(8*(a[i]**4-x**4))
    T[i]=sci.romberg(f,0,a[i]-0.04)

pyplot.plot(a,T)
